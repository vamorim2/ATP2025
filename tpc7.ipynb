# %% [markdown]
# # Aula Prática 7 (guião)
# ### Semana de 27 a 31 de Outubro de 2025
# ### José Carlos Ramalho e Luís Cunha
# ### Sinopsis:
#
# * Consolidação e aferição de tudo o que foi feito até ao momento.
#
# ---

# %% [markdown]
# ### Assunto: Frações
# Vamos pensar num modelo: o que é uma fração estruturalmente?

# %%
# Modelo duma fração
f1 = ???  # 1/3

# Modelo duma lista de frações
lf1 = [???] # 1/2, 1/3, 1/4

# %% [markdown]
# ### Construtor

# %%
def criarFracao(numerador, denominador):
    return # ???

def verFracao(f):
    # ???
    return

verFracao(f1)

# %%
f1 = criarFracao(2,3)
verFracao(f1)

# %% [markdown]
# ### Simplificação de frações

# %%
def simplificarFracao(f):
    return # ???

print(simplificarFracao((55, 80)))

# %%
verFracao(simplificarFracao(criarFracao(21, 140)))

# %% [markdown]
# ### Frações equivalentes
#
# Defina uma função que recebe duas frações como argumento e devolve `True` se as frações são equivalentes e `False` caso contrário.

# %%
def equivalenteFracao(f1,f2):
    # ???
    return # ???

equivalenteFracao((1,2), (14,28))

# %% [markdown]
# ## Operações sobre frações

# %%
def somarFrac(f1, f2):
    return # ???

f1 = criarFracao(15, 21)
f2 = criarFracao(5,7)
verFracao(somarFrac(f1,f2))
verFracao(somarFrac((1,2),(1,2)))

# %%
listaFrac = [f1, f2, criarFracao(125,1000), (8,12)]
listaFrac2 = []
import random
for i in range(1,20):
    n = random.randrange(1, 10)
    d = random.randrange(2, 20)
    listaFrac2.append(criarFracao(n,d))
print(listaFrac2)

# %% [markdown]
# ### Soma uma lista de frações

# %%
def somarListaFrac(lista):
    # ???
    return # ???

verFracao(somarListaFrac(listaFrac))
verFracao(somarListaFrac(listaFrac2))

# %% [markdown]
# ### Multiplica 2 frações

# %%
def multFrac(f1, f2):
    # ???
    return # ???

# %% [markdown]
# ### Ordenar uma lista de frações por ordem decrescente

# %%
def ordenaFracDec(lista):
    x = sorted # ???
    return x

print(ordenaFracDec(listaFrac))

# %% [markdown]
# ### Guardar uma lista de frações num ficheiro

# %%
def gravaListaFrac(fnome, lista):
    # ???
    return

# %%
gravaListaFrac("fracoes.txt", listaFrac)

# %% [markdown]
# ### Recuperar uma lista de frações dum ficheiro

# %%
def carregaListaFrac(fnome):
    res = []
    # ???
    return res

# %%
listaAula = carregaListaFrac("fracoes.txt")
print(listaAula)

# %% [markdown]
# ---
#
# ## TPC7: Teste de aferição
#
# Resolva os problemas apresentados a seguir.

# %% [markdown]
# ### tpc-1. Especifique as seguintes listas em compreensão:

# %% [markdown]
# #### a) Lista formada pelos elementos que não são comuns às duas listas:

# %%
lista1 = [1, 2, 3, 4, 5]
lista2 = [4, 5, 6, 7, 8]  
ncomuns = [...]
# Resultado esperado: [1,2,3,7,8]

def resultadolistas(lista1, lista2):
    ncomuns = []
    for elem in lista1:
        if elem not in lista2:
            ncomuns.append(elem)
    for elem in lista2:
        if elem not in lista1:
            ncomuns.append(elem)
    return ncomuns
            
resultadolistas(lista1, lista2)    
print(ncomuns)

# %% [markdown]
# #### b) Lista formada pelas palavras do texto compostas por mais de 3 letras:

# %%
texto = """Vivia há já não poucos anos algures num concelho do Ribatejo 
    um pequeno lavrador e negociante de gado chamado Manuel Peres Vigário"""
lista = [...]
# Resultado esperado: ['Vivia', 'poucos', 'anos', 'algures', 'concelho', ...]

def palavrasmaiorque3(texto):
    lista = []
    palavras = texto.split()
    for palavra in palavras:
        if len(palavra) > 3:
            lista.append(palavra)
    return lista

palavrasmaiorque3(texto)

# %% [markdown]
# #### c) Lista formada por pares do tipo (índice, valor) com os valores da lista dada:

# %%
lista = ['anaconda', 'burro', 'cavalo', 'macaco']
listaRes = [...]
# Resultado esperado: [(1,'anaconda'), (2,'burro'), (3,'cavalo'), (4,'macaco')]

def parescomvalores(lista):
    listaRes = []
    for i in range(len(lista)):
        tuplo = (i+1, lista[i])
        listaRes.append(tuplo)
    return listaRes

parescomvalores(lista)
# Out:
# [(1, 'anaconda'), (2, 'burro'), (3, 'cavalo'), (4, 'macaco')]

# %% [markdown]
# ### tpc-2. À semelhança do que foi feito nas aulas, realize as seguintes tarefas:

# %% [markdown]
# #### a) Especifique uma função que dada uma string e uma substring não vazia, calcula  o número de vezes em que a substring aparece na string, sem que haja sobreposição de substrings:

# %%
def strCount(string, substring):
    string = string.split()
    i = 0
    for pal in string:
        if pal == substring:
            i = i + 1
    return i

strCount("catcowcat", "cat") # --> 2
strCount("catcowcat", "cow") # --> 1
strCount("catcowcat", "dog") # --> 0
# Out:
# 0

# %% [markdown]
# #### b) Especifique uma função que recebe uma lista de números inteiros positivos e devolve o menor produto que for possível calcular multiplicando os 3 menores inteiros da lista:

# %%
def produtoM3(lista):
    menor = -1000000
    multiplicar = []
    i = 0
    while i < 3:
        for elem in lista:
            if elem > menor:
                menor = elem
                multiplicar.append(elem)
                lista.remove(elem)
    i = i + 1
    
    return  multiplicar[0] * multiplicar[1] * multiplicar[2]  

print(produtoM3([12,3,7,10,12,8,9]))
# Resultado esperado: 168 = 3 * 7 * 8

# %% [markdown]
# #### c) Especifique uma função que dado um número inteiro positivo, repetidamente adiciona os seus dígitos até obter apenas um dígito que é retornado como resultado:

# %%
# Input: 38
# Output: 2
# Explicação: 3 + 8 = 11, 1 + 1 = 2.

# Input: 777
# Output: 3
# Explicação: 7 + 7 + 7 = 21, 2 + 1 = 3.

def reduxInt(n):
    tamanho = len(str(n))
    while tamanho > 1:
        soma = 0
        for x in str(n):
            soma = soma + int(x)
        n = soma
        tamanho = len(str(n))
    return n

reduxInt(123456)
# Out:
# 3

# %% [markdown]
# #### d) Especifique uma função que recebe duas strings, `string1` e `string2`, e devolve o índice da primeira ocorrência de `string2` em `string1`, caso não ocorra nenhuma vez a função deverá retornar `-1`:

# %%
# Invocação: indexOf("Hoje está um belo dia de sol!", "belo")
# Resultado: 13

# Invocação: indexOf("Hoje está um belo dia de sol!", "chuva")
# Resultado: -1

def myIndexOf(s1, s2):
    cond = False
    palavras1= s1.split()
    for elem in range(len(palavras1)):
        if palavras1[elem] == s2:
            print(s1.index(s2))
            cond = True
            return s1.index(s2)
    if cond==False :
        print(-1)


myIndexOf("Hoje está um belo dia de sol!", "belo")
myIndexOf("Hoje está um belo dia de sol!", "chuva")
# Out:
# 13
# -1

# %% [markdown]
# ### tpc-3. A Rede Social
#
# Considere que a informação sobre uma rede social está armazenada numa lista de dicionários.
#
# Cada dicionário, correspondente a um _post_ e tem chaves `id`, `conteudo`, `autor`, `dataCriacao` e `comentarios`.
# Por sua vez, `comentarios` é uma lista de dicionários com chaves `comentario` e `autor`.
#
# Considere o seguinte exemplo:
#
# ```
#     MyFaceBook = [{
#         'id': 'p1',
#         'conteudo': 'A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor
#     tem de realizar...',
#         'autor': 'jcr',
#         'dataCriacao': '2023-07-20',
#         'comentarios': [
#             {
#                 'comentario': 'Completamente de acordo...',
#                 'autor': 'prh'
#             },
#             {
#                 'comentario': 'Mas há quem goste...',
#                 'autor': 'jj'
#             }
#         ]},
#         {
#             'id': 'p2',
#             ...
#         },
#         ...
#         ]
# ```

# %% [markdown]
# Defina as seguintes funções de manipulação e consulta da rede social:

# %% [markdown]
# #### a) `quantosPost`, que indica quantos posts estão registados:

# %%
MyFaceBook = [
    {
    'id': 'p1', 
    'conteudo': '''A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor
tem de realizar...''', 
    'autor': 'jcr', 
    'dataCriacao': '2023-07-20', 
    'comentarios': [
        {
            'comentario': 'Completamente de acordo...',
            'autor': 'prh'
        },
        {
            'comentario': 'Mas há quem goste...',
            'autor': 'jj'
        }
    ]},
    {
        'id': 'p2', 
        'conteudo': '''exemplo de uma string com um comentátio''',
        'autor': 'vsa',
        'dataCriacao': '2025-11-03',
        'comentarios': [
            {
                'comentario': 'exemplo de comentário',
                'autor': 'abc'
            }
        ]
    }
    ]

def quantosPost(redeSocial):
    return len(redeSocial)

quantosPost(MyFaceBook)
# Out:
# 2

# %% [markdown]
# #### b)  `postsAutor`, que devolve a lista de posts de um determinado autor:

# %%
def postsAutor(redeSocial, autor):
    postautor = []
    for post in redeSocial:
        if post['autor'] == autor:
            postautor.append(post)
    return postautor

postsAutor(MyFaceBook, 'jcr') , postsAutor(MyFaceBook, 'vsa')
# Out:
# ([{'id': 'p1',
#    'conteudo': 'A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor\ntem de realizar...',
#    'autor': 'jcr',
#    'dataCriacao': '2023-07-20',
#    'comentarios': [{'comentario': 'Completamente de acordo...',
#      'autor': 'prh'},
#     {'comentario': 'Mas há quem goste...', 'autor': 'jj'}]}],
#  [{'id': 'p2',
#    'conteudo': 'exemplo de uma string com um comentátio',
#    'autor': 'vsa',
#    'dataCriacao': '2025-11-03',
#    'comentarios': [{'comentario': 'exemplo de comentário', 'autor': 'abc'}]}])

# %% [markdown]
# #### c) `autores`, que devolve a lista de autores de posts ordenada alfabeticamente:

# %%
def autores(redeSocial):
    listautores = []
    for post in redeSocial:
        autor = post['autor']
        listautores.append(autor)
        sort = sorted(set(listautores))   
    return sort

autores(MyFaceBook)
# Out:
# ['jcr', 'vsa']

# %% [markdown]
# #### d) `insPost`, que acrescenta um novo post à rede social a partir dos parâmetros recebidos e devolve a nova rede social.
#
# O campo `id` devrá ser calculado a partir dos já existentes, por exemplo, se a rede tiver posts com id `p1`, `p2` e `p3`, o novo `id` deverá ser `p4`.

# %%
def insPost(redeSocial, conteudo, autor, dataCriacao, comentarios):
    novoid = 'p' + str(len(redeSocial) + 1)
    novopost = {
        'id': novoid,
        'conteudo': conteudo,
        'autor': autor,
        'dataCriacao': dataCriacao,
        'comentarios': comentarios
    }
    redeSocial.append(novopost)
    return 

insPost(MyFaceBook, 'Novo post', 'efg', '2025-10-04', [])

print(MyFaceBook)
# Out:
# [{'id': 'p1', 'conteudo': 'A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor\ntem de realizar...', 'autor': 'jcr', 'dataCriacao': '2023-07-20', 'comentarios': [{'comentario': 'Completamente de acordo...', 'autor': 'prh'}, {'comentario': 'Mas há quem goste...', 'autor': 'jj'}]}, {'id': 'p2', 'conteudo': 'exemplo de uma string com um comentátio', 'autor': 'vsa', 'dataCriacao': '2025-11-03', 'comentarios': [{'comentario': 'exemplo de comentário', 'autor': 'abc'}]}, {'id': 'p3', 'conteudo': 'Novo post', 'autor': 'efg', 'dataCriacao': '2025-10-04', 'comentarios': []}]

# %% [markdown]
# #### e)  `remPost`, que remove um post da rede, correspondente ao `id` recebido.

# %%
def remPost(redeSocial, id):
    for post in redeSocial:
        if post['id'] == id:
            redeSocial.remove(post)
    return 

remPost(MyFaceBook, 'p3')
print(MyFaceBook)
# Out:
# [{'id': 'p1', 'conteudo': 'A tarefa de avaliação é talvez a mais ingrata das tarefas que um professor\ntem de realizar...', 'autor': 'jcr', 'dataCriacao': '2023-07-20', 'comentarios': [{'comentario': 'Completamente de acordo...', 'autor': 'prh'}, {'comentario': 'Mas há quem goste...', 'autor': 'jj'}]}, {'id': 'p2', 'conteudo': 'exemplo de uma string com um comentátio', 'autor': 'vsa', 'dataCriacao': '2025-11-03', 'comentarios': [{'comentario': 'exemplo de comentário', 'autor': 'abc'}]}]

# %% [markdown]
# #### f) `postsPorAutor`, que devolve uma distribuição de posts por autor (à semelhança do que foi feito nas aulas).

# %%
def postsPorAutor(redeSocial, autor):
    postporautor = {}
    for post in redeSocial:
        autor = post['autor']
        postporautor[autor].append(post)
    return postporautor

postsPorAutor(MyFaceBook, 'jcr'), postsPorAutor(MyFaceBook, 'vsa')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 8
#       5         postporautor[autor].append(post)
#       6     return postporautor
# ----> 8 postsPorAutor(MyFaceBook, 'jcr'), postsPorAutor(MyFaceBook, 'vsa')
#
# Cell In[16], line 5, in postsPorAutor(redeSocial, autor)
#       3 for post in redeSocial:
#       4     autor = post['autor']
# ----> 5     postporautor[autor].append(post)
#       6 return postporautor
#
# KeyError: 'jcr'

# %% [markdown]
# #### g) `comentadoPor`, que recebe um autor e devolve a lista de posts comentados por esse autor.

# %%
def comentadoPor(redeSocial, autor):
    autorecoment = []
    for post in redeSocial:
        for comentario in post['comentarios']:
            if comentario['autor'] == autor:
                autorecoment.append(comentario)
    return autorecoment

comentadoPor(MyFaceBook, 'prh') , comentadoPor(MyFaceBook, 'abc')
# Out:
# ([{'comentario': 'Completamente de acordo...', 'autor': 'prh'}],
#  [{'comentario': 'exemplo de comentário', 'autor': 'abc'}])
